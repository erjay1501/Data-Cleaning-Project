# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = "2020_cleaned_personal_property_list.csv"  # Update this path accordingly
df = pd.read_csv(file_path, encoding='latin1', low_memory=False)
df
# Out:
#        AGENCY_CODE                        STATE_AGENCY      PROPERTY_TYPE  \
# 0               10                      OSU-STILLWATER  PERSONAL PROPERTY
# 1               10                      OSU-STILLWATER  PERSONAL PROPERTY
# 2               10                      OSU-STILLWATER  PERSONAL PROPERTY
# 3               10                      OSU-STILLWATER  PERSONAL PROPERTY
# 4               10                      OSU-STILLWATER  PERSONAL PROPERTY
# ...            ...                                 ...                ...
# 68284          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 68285          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 68286          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 68287          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 68288          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
#
#       PROPERTY_CLASSIFICATION                              PROPERTY_NAME  \
# 0                       OWNED  Data Terminal, Ti (S Cint. Ctr) Mdl 700As
# 1                       OWNED                       Computer, Dell Gx620
# 2                       OWNED             Computer, Dell Dimension 5150C
# 3                       OWNED    Dell Intel Pentium 4 Processor 630 W/Ht
# 4                       OWNED                Vostrp 700, Intel Core2 Duo
# ...                       ...                                        ...
# 68284                     NaN                 3-Way Hydraulic Rear Blade
# 68285                     NaN                           Whitco Preferred
# 68286                     NaN              F3990 Front Deck Mower W/ Cab
# 68287                     NaN               Skid Mounted Pressure Washer
# 68288                     NaN                       Bull Wheel Tensioner
#
#       DATE_ACQUIRED_OR_INSTALLED  VALUE_OR_COST IT_OR_NON-IT
# 0                     1977-08-15       20600.00           IT
# 1                     2005-08-17        1435.04           IT
# 2                     2006-05-25        1337.87           IT
# 3                     2007-05-17         936.16           IT
# 4                     2007-08-27        1138.88           IT
# ...                          ...            ...          ...
# 68284                 2018-06-29        6177.69          NaN
# 68285                 2018-08-31        7169.00          NaN
# 68286                 2019-04-15       28331.72          NaN
# 68287                 2019-04-11        6389.05          NaN
# 68288                 2018-08-01       67900.00          NaN
#
# [68289 rows x 8 columns]

# %%
### DESCRIPTIVE ANALYSIS ###
print("Total number of records in the dataset:", len(df))
print("Unique state agencies:", df['STATE_AGENCY'].nunique())
print("Most common property types:")
print(df['PROPERTY_TYPE'].value_counts().head(10))
print("\nProperty classification distribution:")
print(df['PROPERTY_NAME'].value_counts())
print("\nIT vs Non-IT distribution:")
print(df['IT_OR_NON-IT'].value_counts())
# Out:
# Total number of records in the dataset: 68289
# Unique state agencies: 77
# Most common property types:
# PROPERTY_TYPE
# PERSONAL PROPERTY    68289
# Name: count, dtype: int64
#
# Property classification distribution:
# PROPERTY_NAME
# Dell Marketing Lp                            455
# Radar, Stalker Dual Dsr 2X, Counting Unit    433
# Laptop                                       422
# Radar, Stalker Dual Dsr 2X, Antenna          404
# Cpu                                          373
#                                             ...
# Ice Maker - Fisher Scientific                  1
# Idxa Bone Densitometer                         1
# In1120-Dt Mosaic Digital Camera                1
# In1820 2Mb C-Mnt Camera                        1
# Bull Wheel Tensioner                           1
# Name: count, Length: 44792, dtype: int64
#
# IT vs Non-IT distribution:
# IT_OR_NON-IT
# NON-IT    35321
# IT        32848
# Name: count, dtype: int64

# %%
### FINANCIAL ANALYSIS ###
# Convert Value or Cost to numeric
df['VALUE_OR_COST'] = pd.to_numeric(df['VALUE_OR_COST'], errors='coerce')

# %%
print("\nTotal value of all properties:", df['VALUE_OR_COST'].sum())
print("Average cost of IT properties:", df[df['IT_OR_NON-IT'] == 'IT']['VALUE_OR_COST' ].mean())
print("Average cost of Non-IT properties:", df[df['IT_OR_NON-IT'] == 'NON-IT']['VALUE_OR_COST'].mean())
# Out:
# Total value of all properties: 1938882271.9799995
# Average cost of IT properties: 11399.3555964459
# Average cost of Non-IT properties: 45404.446667243916

# %%
# Most expensive property
most_expensive = df.loc[df['VALUE_OR_COST'].idxmax()]
print("Most expensive property:", most_expensive['PROPERTY_NAME'], "- Value:", most_expensive['VALUE_OR_COST'])

# Agency with the highest total property value
top_agency = df.groupby('STATE_AGENCY')['VALUE_OR_COST'].sum().idxmax()
print("Agency with highest total property value:", top_agency)
# Out:
# Most expensive property: Broken Arrow Afrc - Value: 66061825.0
# Agency with highest total property value: OMES

# %%
### CATEGORICAL ANALYSIS ###
print("\nTop 10 most frequently occurring property names:")
print(df['PROPERTY_NAME'].value_counts().head(10))
print("Agencies with the most diverse range of property types:")
print(df.groupby('STATE_AGENCY')['PROPERTY_TYPE'].nunique().sort_values(ascending=False).head(10))
# Out:
# Top 10 most frequently occurring property names:
# PROPERTY_NAME
# Dell Marketing Lp                            455
# Radar, Stalker Dual Dsr 2X, Counting Unit    433
# Laptop                                       422
# Radar, Stalker Dual Dsr 2X, Antenna          404
# Cpu                                          373
# Truck                                        373
# Trailer                                      333
# Radio, Apx 6500, Geo/Gps                     294
# Snow Plow                                    294
# Video, Dv-1E Overhead                        278
# Name: count, dtype: int64
# Agencies with the most diverse range of property types:
# STATE_AGENCY
# ABSTRACTORS BOARD                                 1
# NORTHERN OKLAHOMA COLLEGE                         1
# OKLAHOMA TURNPIKE AUTHORITY                       1
# OKLAHOMA STUDENT LOAN AUTHORITY                   1
# OKLAHOMA REAL ESTATE COMMISSION                   1
# OKLAHOMA MUNICIPAL POWER AUTHORITY                1
# OKLAHOMA LOTTERY COMMISSION                       1
# OKLAHOMA DEPARTMENT OF REHABILITATION SERVICES    1
# OKLAHOMA CITY COMMUNITY COLLEGE                   1
# NORTHEASTERN STATE UNIVERSITY                     1
# Name: PROPERTY_TYPE, dtype: int64

# %%
### DATA VISUALIZATION ###
# Histogram of property values
plt.figure(figsize=(10,5))
df['VALUE_OR_COST'].dropna().hist(bins=50, color='purple', edgecolor='black')
plt.yscale('log')
plt.title("Distribution of Property Values")
plt.xlabel("VALUE_OR_COST")
plt.ylabel("Count (log scale)")
plt.show()

# %%
# Properties per agency (top 10)
plt.figure(figsize=(12,6))
df['STATE_AGENCY'].value_counts().head(10).plot(kind='bar', color='green')
plt.title("Top 10 Agencies by Number of Properties")
plt.xlabel("Agency")
plt.ylabel("Count")
plt.xticks(rotation=75)
plt.show()

# %%
# IT vs Non-IT properties
plt.figure(figsize=(6,6))
df['IT_OR_NON-IT'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'red'])
plt.title("IT vs Non-IT Property Distribution")
plt.ylabel("")
plt.show()

# %%
# Property Classification Distribution
plt.figure(figsize=(10,5))
df['PROPERTY_TYPE'].value_counts().plot(kind='bar', color='cyan')
plt.title("Distribution of Property Classifications")
plt.xlabel("Classification")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Top agencies by total property value
plt.figure(figsize=(12,6))
df.groupby('STATE_AGENCY')['VALUE_OR_COST'].sum().nlargest(10).plot(kind='bar', color='brown')
plt.title("Top 10 Agencies by Total Property Value")
plt.xlabel("Agency")
plt.ylabel("Total Value")
plt.xticks(rotation=75)
plt.show()

# %%
# Top 10 most expensive properties
plt.figure(figsize=(12,6))
df.nlargest(10, 'VALUE_OR_COST').set_index('PROPERTY_NAME')['VALUE_OR_COST'].plot(kind='bar', color='pink')
plt.title("Top 10 Most Expensive Properties")
plt.xlabel("Property Name")
plt.ylabel("Value")
plt.xticks(rotation=75)
plt.show()

# %%
# Box plot of property value by classification
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='PROPERTY_TYPE', y='VALUE_OR_COST')
plt.yscale("log")
plt.title("Property Value Distribution by Classification")
plt.xticks(rotation=45)
plt.show()

# %%
print("\nAnalysis completed.")
# Out:
# Analysis completed.
