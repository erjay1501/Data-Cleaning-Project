# %%
import pandas as pd
import numpy as np

# %%
# Load dataset with appropriate encoding
file_path = "2020-personal-property.csv"
df = pd.read_csv(file_path, encoding='latin1')

# %%
# Drop unnecessary unnamed columns
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

# %%
# Trim whitespace from column names, replace spaces with underscores, and convert to upper case
df.columns = df.columns.str.strip().str.replace(' ', '_').str.upper().str.replace('/', '_OR_')
df
# Out:
#         AGENCY_CODE                        STATE_AGENCY      PROPERTY_TYPE  \
# 0                10                      OSU-STILLWATER  PERSONAL PROPERTY
# 1                10                      OSU-STILLWATER  PERSONAL PROPERTY
# 2                10                      OSU-STILLWATER  PERSONAL PROPERTY
# 3                10                      OSU-STILLWATER  PERSONAL PROPERTY
# 4                10                      OSU-STILLWATER  PERSONAL PROPERTY
# ...             ...                                 ...                ...
# 149368          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 149369          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 149370          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 149371          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
# 149372          981  OKLAHOMA MUNICIPAL POWER AUTHORITY  PERSONAL PROPERTY
#
#        PROPERTY_CLASSIFICATION                              PROPERTY_NAME  \
# 0                        OWNED  DATA TERMINAL, TI (S CINT. CTR) MDL 700AS
# 1                        OWNED                       COMPUTER, DELL GX620
# 2                        OWNED             COMPUTER, DELL DIMENSION 5150C
# 3                        OWNED    DELL INTEL PENTIUM 4 PROCESSOR 630 W/HT
# 4                        OWNED                VOSTRP 700, INTEL CORE2 DUO
# ...                        ...                                        ...
# 149368                     NaN          ZERO TURN MOWER W/ VAC - 61" DECK
# 149369                     NaN               ROTARY BOOM MOWER ATTACHMENT
# 149370                     NaN              F3990 FRONT DECK MOWER W/ CAB
# 149371                     NaN               SKID MOUNTED PRESSURE WASHER
# 149372                     NaN                       BULL WHEEL TENSIONER
#
#        DATE_ACQUIRED_OR_INSTALLED VALUE_OR_COST IT_OR_NON-IT
# 0                       8/15/1977   $20,600.00            IT
# 1                       8/17/2005    $1,435.04            IT
# 2                       5/25/2006    $1,337.87            IT
# 3                       5/17/2007      $936.16            IT
# 4                       8/27/2007    $1,138.88            IT
# ...                           ...           ...          ...
# 149368                        NaN   $11,344.75           NaN
# 149369                        NaN   $43,544.76           NaN
# 149370                  4/15/2019   $28,331.72           NaN
# 149371                  4/11/2019    $6,389.05           NaN
# 149372                   8/1/2018   $67,900.00           NaN
#
# [149373 rows x 8 columns]

# %%
# Handle missing values: Drop rows where essential columns are missing
essential_cols = ["AGENCY_CODE", "STATE_AGENCY", "PROPERTY_NAME", "VALUE_OR_COST", "DATE_ACQUIRED_OR_INSTALLED"]
df.dropna(subset=essential_cols, inplace=True)

# %%
# Clean 'VALUE_OR_COST' column by removing extra spaces and converting to numeric
df['VALUE_OR_COST'] = df['VALUE_OR_COST'].astype(str).str.strip().replace('[\$,]', '', regex=True)
df['VALUE_OR_COST'] = pd.to_numeric(df['VALUE_OR_COST'], errors='coerce')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/wm/3j20np153f92h_05z976byhh0000gn/T/ipykernel_87762/768682255.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df['VALUE_OR_COST'] = df['VALUE_OR_COST'].astype(str).str.strip().replace('[\$,]', '', regex=True)

# %%
# Standardize 'DATE_ACQUIRED_OR_INSTALLED' format
df['DATE_ACQUIRED_OR_INSTALLED'] = pd.to_datetime(df['DATE_ACQUIRED_OR_INSTALLED'], errors='coerce')

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Drop 'YEAR' column if it exists
df.drop(columns=['YEAR', 'COUNT'], errors='ignore', inplace=True)

# %%
# Normalize text columns
df['STATE_AGENCY'] = df['STATE_AGENCY'].str.upper().str.strip()
df['PROPERTY_NAME'] = df['PROPERTY_NAME'].str.title().str.strip()

# %%
# Validate 'IT_OR_NON-IT' column
df['IT_OR_NON-IT'] = df['IT_OR_NON-IT'].str.upper().replace({'IT': 'IT', 'NON-IT': 'NON-IT'})
df['IT_OR_NON-IT'] = df['IT_OR_NON-IT'].apply(lambda x: x if x in ['IT', 'NON-IT'] else np.nan)

# %%
# Save the cleaned dataset
df.to_csv("2020_cleaned_personal_property_list.csv", index=False)

# %%
# Display cleaned dataset
df.head()
# Out:
#    AGENCY_CODE    STATE_AGENCY      PROPERTY_TYPE PROPERTY_CLASSIFICATION  \
# 0           10  OSU-STILLWATER  PERSONAL PROPERTY                   OWNED
# 1           10  OSU-STILLWATER  PERSONAL PROPERTY                   OWNED
# 2           10  OSU-STILLWATER  PERSONAL PROPERTY                   OWNED
# 3           10  OSU-STILLWATER  PERSONAL PROPERTY                   OWNED
# 4           10  OSU-STILLWATER  PERSONAL PROPERTY                   OWNED
#
#                                PROPERTY_NAME DATE_ACQUIRED_OR_INSTALLED  \
# 0  Data Terminal, Ti (S Cint. Ctr) Mdl 700As                 1977-08-15
# 1                       Computer, Dell Gx620                 2005-08-17
# 2             Computer, Dell Dimension 5150C                 2006-05-25
# 3    Dell Intel Pentium 4 Processor 630 W/Ht                 2007-05-17
# 4                Vostrp 700, Intel Core2 Duo                 2007-08-27
#
#    VALUE_OR_COST IT_OR_NON-IT
# 0       20600.00           IT
# 1        1435.04           IT
# 2        1337.87           IT
# 3         936.16           IT
# 4        1138.88           IT
