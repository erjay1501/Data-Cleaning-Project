# %%
import pandas as pd
import numpy as np

# %%
# Load dataset with appropriate encoding
file_path = "2024-personal-property-inventory.csv"
df = pd.read_csv(file_path, encoding='latin1')
df
# Out:
# /var/folders/wm/3j20np153f92h_05z976byhh0000gn/T/ipykernel_88787/2763877326.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='latin1')
#         AGENCY CODE                STATE AGENCY      PROPERTY TYPE  \
# 0              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 1              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 2              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 3              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 4              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# ...             ...                         ...                ...
# 235885          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235886          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235887          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235888          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235889          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
#
#        PROPERTY CLASSIFICATION  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 235885                   OWNED
# 235886                   OWNED
# 235887                   OWNED
# 235888                   OWNED
# 235889                   OWNED
#
#                                             PROPERTY NAME  \
# 0                                       RECEPTIONIST DESK
# 1                                          MAIL ROOM AREA
# 2                             DESK:DESKS AND TABLES, WOOD
# 3                                                 PRINTER
# 4                                        DOCUMENT SCANNER
# ...                                                   ...
# 235885  WIDEBAND CONTINUOUS-WAVE CHARACTERIZATION\nPLA...
# 235886               BUS, 2023 MCI D45CRTLE B9115 LP28632
# 235887  ART, UNTITLED SECONDARIES W/ PRIMARIES, JASPER...
# 235888                                   BOILER CONTROLS,
# 235889  SPECTROMETER, BRUKER BIOSPIN 800MHZ NMR W/ CRY...
#
#        DATE ACQUIRED OR INSTALLED VALUE OR COST IT/NON-IT
# 0                       9 21 2010       2695.74    NON-IT
# 1                       9 15 2010          4688    NON-IT
# 2                       1 31 2019       2822.84    NON-IT
# 3                       3 24 2006           520        IT
# 4                       2 28 2011          6475        IT
# ...                           ...           ...       ...
# 235885                  5 06 2021      759912.3    NON-IT
# 235886                  1 02 2024      785962.0    NON-IT
# 235887                  3 28 2014     1200000.0    NON-IT
# 235888                  1 10 2006     1994678.0    NON-IT
# 235889                  4 23 2019    2776533.06    NON-IT
#
# [235890 rows x 8 columns]

# %%
# Drop unnecessary unnamed columns
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

# %%
# Trim whitespace from column names, replace spaces with underscores, and convert to upper case
df.columns = df.columns.str.strip().str.replace(' ', '_').str.upper().str.replace('/', '_OR_')
df
# Out:
#         AGENCY_CODE                STATE_AGENCY      PROPERTY_TYPE  \
# 0              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 1              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 2              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 3              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 4              20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# ...             ...                         ...                ...
# 235885          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235886          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235887          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235888          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
# 235889          NaN   OKLAHOMA STATE UNIVERSITY  PERSONAL PROPERTY
#
#        PROPERTY_CLASSIFICATION  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 235885                   OWNED
# 235886                   OWNED
# 235887                   OWNED
# 235888                   OWNED
# 235889                   OWNED
#
#                                             PROPERTY_NAME  \
# 0                                       RECEPTIONIST DESK
# 1                                          MAIL ROOM AREA
# 2                             DESK:DESKS AND TABLES, WOOD
# 3                                                 PRINTER
# 4                                        DOCUMENT SCANNER
# ...                                                   ...
# 235885  WIDEBAND CONTINUOUS-WAVE CHARACTERIZATION\nPLA...
# 235886               BUS, 2023 MCI D45CRTLE B9115 LP28632
# 235887  ART, UNTITLED SECONDARIES W/ PRIMARIES, JASPER...
# 235888                                   BOILER CONTROLS,
# 235889  SPECTROMETER, BRUKER BIOSPIN 800MHZ NMR W/ CRY...
#
#        DATE_ACQUIRED_OR_INSTALLED VALUE_OR_COST IT_OR_NON-IT
# 0                       9 21 2010       2695.74       NON-IT
# 1                       9 15 2010          4688       NON-IT
# 2                       1 31 2019       2822.84       NON-IT
# 3                       3 24 2006           520           IT
# 4                       2 28 2011          6475           IT
# ...                           ...           ...          ...
# 235885                  5 06 2021      759912.3       NON-IT
# 235886                  1 02 2024      785962.0       NON-IT
# 235887                  3 28 2014     1200000.0       NON-IT
# 235888                  1 10 2006     1994678.0       NON-IT
# 235889                  4 23 2019    2776533.06       NON-IT
#
# [235890 rows x 8 columns]

# %%
# Fix inconsistency in 'PROPERTY_TYPE' column
df['PROPERTY_TYPE'] = df['PROPERTY_TYPE'].str.upper().str.strip()

# %%
# Rename the first column properly if it contains encoding issues
df.rename(columns={df.columns[0]: "AGENCY_CODE"}, inplace=True)

# %%
# Handle missing values: Drop rows where essential columns are missing
essential_cols = ["AGENCY_CODE", "STATE_AGENCY", "PROPERTY_NAME", "VALUE_OR_COST", "DATE_ACQUIRED_OR_INSTALLED"]
df.dropna(subset=essential_cols, inplace=True)

# %%
# Clean 'VALUE_OR_COST' column by removing extra spaces and converting to numeric
df['VALUE_OR_COST'] = df['VALUE_OR_COST'].astype(str).str.strip().replace('[\$,]', '', regex=True)
df['VALUE_OR_COST'] = pd.to_numeric(df['VALUE_OR_COST'], errors='coerce')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/wm/3j20np153f92h_05z976byhh0000gn/T/ipykernel_88787/768682255.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df['VALUE_OR_COST'] = df['VALUE_OR_COST'].astype(str).str.strip().replace('[\$,]', '', regex=True)

# %%
# Standardize 'DATE_ACQUIRED_OR_INSTALLED' format
df['DATE_ACQUIRED_OR_INSTALLED'] = pd.to_datetime(df['DATE_ACQUIRED_OR_INSTALLED'], errors='coerce')

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Drop 'YEAR' column if it exists
df.drop(columns=['YEAR', 'COUNT'], errors='ignore', inplace=True)

# %%
# Normalize text columns
df['STATE_AGENCY'] = df['STATE_AGENCY'].str.upper().str.strip()
df['PROPERTY_NAME'] = df['PROPERTY_NAME'].str.title().str.strip()

# %%
# Validate 'IT_OR_NON-IT' column
df['IT_OR_NON-IT'] = df['IT_OR_NON-IT'].str.upper().replace({'IT': 'IT', 'NON-IT': 'NON-IT'})
df['IT_OR_NON-IT'] = df['IT_OR_NON-IT'].apply(lambda x: x if x in ['IT', 'NON-IT'] else np.nan)

# %%
# Save the cleaned dataset
df.to_csv("2024_cleaned_personal_property_list.csv", index=False)

# %%
# Display cleaned dataset
df.head()
# Out:
#    AGENCY_CODE                STATE_AGENCY      PROPERTY_TYPE  \
# 0         20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 1         20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 2         20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 3         20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
# 4         20.0  OKLAHOMA ACCOUNTANCY BOARD  PERSONAL PROPERTY
#
#   PROPERTY_CLASSIFICATION                PROPERTY_NAME  \
# 0                     NaN            Receptionist Desk
# 1                     NaN               Mail Room Area
# 2                     NaN  Desk:Desks And Tables, Wood
# 3                     NaN                      Printer
# 4                     NaN             Document Scanner
#
#   DATE_ACQUIRED_OR_INSTALLED  VALUE_OR_COST IT_OR_NON-IT
# 0                 2010-09-21        2695.74       NON-IT
# 1                 2010-09-15        4688.00       NON-IT
# 2                 2019-01-31        2822.84       NON-IT
# 3                 2006-03-24         520.00           IT
# 4                 2011-02-28        6475.00           IT
